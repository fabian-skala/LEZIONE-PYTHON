# %% [markdown]
# ### Piccolo tutorila su configurazione ambiente jupyter

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# ### variabili

# %%
x = 5
nome = "andrea"
finito = True
y = 7.42

# %%
print(x)
print(nome)
print(finito)
print(y)
# Out:
# 5
# andrea
# True
# 7.42

# %% [markdown]
# ### tuple e liste

# %%
# tupla
coordinate = (5,8)
print(coordinate)
#lista
lista1 = ["rosso","verde","blu"]
lista2 = [1,2,6,9,20]
print(lista1)
print(lista2)
# Out:
# (5, 8)
# ['rosso', 'verde', 'blu']
# [1, 2, 6, 9, 20]

# %% [markdown]
# ### selezione e iterazione

# %%
# selezione
if finito:
    print("ho finito")
else:
    print("non ho finito")
# Out:
# ho finito

# %%
for colore in lista1:
    print(colore)
    for numero in lista2:
        print(numero)
# Out:
# rosso
# 1
# 2
# 6
# 9
# 20
# verde
# 1
# 2
# 6
# 9
# 20
# blu
# 1
# 2
# 6
# 9
# 20

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
